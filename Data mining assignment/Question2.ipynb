# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# %% [markdown]
# <i>Question 2</i>

# %% [markdown]
# For every year, find the lean and peak months of visit in terms of fees received.<br>
# For every country and continent, find the lean and peak quarters of visit.<br>

# %% [markdown]
# <h3>Part 1</h3>

# %%
df_ = pd.read_excel(r"data\TourismData-2013\MONTH-WISE FEE FROM TOURISM (CRORE) IN INDIA.xlsx");
summary_data = []

for year in df_.columns[1:]:
    max_index = df_[year].idxmax()
    min_index = df_[year].idxmin()
    
    max_month = df_.at[max_index, 'MONTH']
    min_month = df_.at[min_index, 'MONTH']
    max_value = df_[year].max()
    min_value = df_[year].min()
    
    summary_data.append({
        'Year': year,
        'Peak Month': max_month,
        'Highest Fee (Crore)': max_value,
        'Leanest Month': min_month,
        'Lowest Fee (Crore)': min_value
    })
    
summary_df = pd.DataFrame(summary_data)

print(summary_df)
print("\nTable 1: Peak and leanest months for each year in terms of fees received")
# Out:
#    Year Peak Month  Highest Fee (Crore) Leanest Month  Lowest Fee (Crore)
# 0  2022   December                19527       January                3843
# 1  2021   December                 8452           May                1730
# 2  2020    January                20200         April                  71
# 3  2019   December                22631           May               13642
# 4  2018   December                19474           May               12752
# 5  2017   December                19381           May               12255
# 6  2016   December                16558           May               10260
# 7  2015   December                14152           May                9505
# 8  2014   December                12988           May                7936
# 9  2013   December                11994           May                6627
#
# Table 1: Peak and leanest months for each year in terms of fees received

# %% [markdown]
# <h3>Part 2</h3>

# %%
years = ['2013','2014','2016','2017','2018','2019','2020','2021','2022']
regions = ['North America', 'Central & South America', 'Western Europe', 'Eastern Europe', 'Africa', 'West Asia', 'South Asia', 'South East Asia', 'East Asia', 'Australasia']

# %%
def find_data(dict_name, year, type, name): # year and type to be provided in string format. type is 'countries' or 'regions'.
    for row in dict_name[year][type]:
        if row[0].lower() == name.lower():
            retval = row.copy()
            retval[1] = int(retval[1])
            return tuple(retval[1:])
    return None

# %%
data = {}
cubes = {}

for y in years:
    data[f'df{y[-2:]}'] = pd.read_excel(rf"data\TourismData-{y}\NATIONALITY-WISE QUARTER-WISE DISTRIBUTION OF FTAs IN INDIA.xlsx") ## to store pandas dataframe

for y in years:
    df = data[f'df{y[-2:]}']
    region_indices = df[df['Country of Nationality'].isin(regions)].index.tolist()
    split_data = [] ## empty list to hold the region separated 2D lists to be created

    # Iterate over the indices, splitting the DataFrame into segments
    for i in range(len(region_indices)):
        # Define the start and end indices for each split
        start_idx = region_indices[i]
        end_idx = region_indices[i + 1] if i + 1 < len(region_indices) else len(df)        
        # Extract the section and convert it to a list of lists (2D list)
        section = df.iloc[start_idx:end_idx].values.tolist()
        split_data.append(section) 
    # Dataframe split into 2D lists based on region
    # Format of 2D lists created : [['North America', nan, nan, nan, nan, nan], ['Canada', 289259, 21.30, 18, 20.60, 40.10], ['USA', 1403399, 15.10, 27, 22.10, 35.80]]
    # 1st row contains the name of the region with empty spaces for sum of features, followed by countries in that region with their features. 

    # print(len(split_data),split_data)
    # Calculate region-wise sum for quarter-wise and total tourists
    for i in range(len(split_data)):
        chunk = split_data[i]
        size = len(chunk[0])
        total = 0
        grp = (size-2)*[0]
        for j in range(1,len(chunk)):
            total+=chunk[j][1]
            for k in range(size-2):
                grp[k]+=chunk[j][2+k]*chunk[j][1]
        chunk[0][1] = int(total)
        
        for k in range(size-2):
            chunk[0][2+k] = grp[k]/total

    for i in range(len(split_data)):
        for j in range(len(split_data[i])):
            for k in range(2,len(split_data[i][j])):
                split_data[i][j][k] = round(split_data[i][j][k]/100,2)
    
    # print(split_data)
    cubes[f'cube{y[-2:]}'] = split_data

# %%
answer = {}
for y in years:
    cube = cubes[f'cube{y[-2:]}']
    ans = {}
    ans['countries'] = []
    ans['regions'] = []

    for chunk in cube:
        ans['regions'].append(chunk[0])
        for country_data in chunk[1:]:
                if(country_data[0] != 'Others'):
                    ans['countries'].append(country_data)
    
    size = len(cube[0][0])
    grp = (size-2)*[0]
    total_overall = 0
    for region in ans['regions']:
        total_overall+=region[1]
        for k in range(size-2):
            grp[k] += region[k+2]*region[1]
    
    ans['overall'] = ['Overall', total_overall]+[round(val/total_overall,2) for val in grp]
    answer[f'{y}'] = ans

# %%
countries = set()
for y in years:
    data = answer[f'{y}']['countries']
    for country in [c_data[0] for c_data in data]:
        countries.add(country)
countries = sorted(list(countries))

# %%
table_c = {} 
table_r = {} 
table_o = {} 
table_c['Country'] = countries
table_r['Continents'] = regions
table_o[' '] = ['Overall']

for y in years:
    if(y == '2014'):
        continue
    table_c[f'{y}'] = []
    for c in countries:
        table_c[f'{y}'].append(find_data(answer, f'{y}', 'countries', c))
    
    table_r[f'{y}'] = []
    for r in regions:
        table_r[f'{y}'].append(find_data(answer, f'{y}', 'regions', r))
    
    table_o[f'{y}'] = [tuple(answer[f'{y}']['overall'][1:])]

df_o = pd.DataFrame(table_o)

df_r = pd.DataFrame(table_r)

df_c = pd.DataFrame(table_c)

# %%
max_quarters = {} 
min_quarters = {}

# Extract years from columns (skip the first 'Continents' column)
years = df_r.columns[1:]

# Iterate over each row (each continent/region)
for i, row in df_r.iterrows():
    region = row['Continents']
    max_quarters[region] = {}
    min_quarters[region] = {}
    
    # Iterate over each year
    for year in years:
        # Extract the tuple from the cell, ignoring the first element (total tourists)
        data = row[year][1:]
        
        # Find the quarter with the max and min fractions
        max_quarter = np.argmax(data) + 1  # Adding 1 to make it 1-based
        min_quarter = np.argmin(data) + 1  # Adding 1 to make it 1-based
        
        # Store the results
        max_quarters[region][year] = f"Quarter {max_quarter}"
        min_quarters[region][year] = f"Quarter {min_quarter}"
    
    # Calculate the average across all years to find the overall max and min quarter
    avg_data = np.mean([row[year][1:] for year in years], axis=0)
    overall_max_quarter = np.argmax(avg_data) + 1
    overall_min_quarter = np.argmin(avg_data) + 1
    
    # Store the overall results
    max_quarters[region]['Overall'] = f"Quarter {overall_max_quarter}"
    min_quarters[region]['Overall'] = f"Quarter{overall_min_quarter}"

max_quarters_df = pd.DataFrame(max_quarters).T
min_quarters_df = pd.DataFrame(min_quarters).T

# %%
print("Table 2: Table showing the quarter with maximum tourists coming from each region for each year and overall:")
print(tabulate(max_quarters_df, headers='keys', tablefmt='grid'))
print("\n")
# Out:
# Table 2: Table showing the quarter with maximum tourists coming from each region for each year and overall:
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# |                         | 2013      | 2016      | 2017      | 2018      | 2019      | 2020      | 2021      | 2022      | Overall   |
# +=========================+===========+===========+===========+===========+===========+===========+===========+===========+===========+
# | North America           | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Central & South America | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Western Europe          | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Eastern Europe          | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Africa                  | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | West Asia               | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 1 | Quarter 4 | Quarter 3 | Quarter 1 |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | South Asia              | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | South East Asia         | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | East Asia               | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Australasia             | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+

# %%
print("\nTable 3: Table showing the quarter with minimum tourists coming from each region for each year and overall:")
print(tabulate(min_quarters_df, headers='keys', tablefmt='grid'))
# Out:
# Table 3: Table showing the quarter with minimum tourists coming from each region for each year and overall:
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# |                         | 2013      | 2016      | 2017      | 2018      | 2019      | 2020      | 2021      | 2022      | Overall   |
# +=========================+===========+===========+===========+===========+===========+===========+===========+===========+===========+
# | North America           | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Central & South America | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Western Europe          | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Eastern Europe          | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter2  |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Africa                  | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | West Asia               | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | South Asia              | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | South East Asia         | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | East Asia               | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Australasia             | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +-------------------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+

# %%
max_quarters_c = {}
min_quarters_c = {}

# Extract years from columns (skip the first 'Continents' column)
years = df_c.columns[1:]

# Iterate over each row (each country)
for i, row in df_c.iterrows():
    country = row['Country']
    max_quarters_c[country] = {}
    min_quarters_c[country] = {}
    
    # Iterate over each year
    for year in years:
        # Extract the tuple from the cell, ignoring the first element (total tourists)
        if row[year]:
            data = row[year][1:]

            # Find the quarter with the max and min fractions
            max_quarter = np.argmax(data) + 1  # Adding 1 to make it 1-based
            min_quarter = np.argmin(data) + 1  # Adding 1 to make it 1-based
            
            # Store the results
            max_quarters_c[country][year] = f"Quarter {max_quarter}"
            min_quarters_c[country][year] = f"Quarter {min_quarter}"
        else:
            max_quarters_c[country][year] = None
            min_quarters_c[country][year] = None
    
    # Calculate the average across all years to find the overall max and min quarter
    avg_data = np.mean([row[year][1:] for year in years if row[year]], axis=0)
    overall_max_quarter = np.argmax(avg_data) + 1
    overall_min_quarter = np.argmin(avg_data) + 1
    
    # Store the overall results
    max_quarters_c[country]['Overall'] = f"Quarter {overall_max_quarter}"
    min_quarters_c[country]['Overall'] = f"Quarter{overall_min_quarter}"

max_quarters_df = pd.DataFrame(max_quarters_c).T
min_quarters_df = pd.DataFrame(min_quarters_c).T

# %%
print("Table 4: Table showing the quarter with maximum tourists coming from each country for each year and overall:")
print(tabulate(max_quarters_df, headers='keys', tablefmt='grid'))
print("\n")
# Out:
# Table 4: Table showing the quarter with maximum tourists coming from each country for each year and overall:
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# |                | 2013      | 2016      | 2017      | 2018      | 2019      | 2020      | 2021      | 2022      | Overall   |
# +================+===========+===========+===========+===========+===========+===========+===========+===========+===========+
# | Afghanistan    | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 2 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Argentina      | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Australia      | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Austria        | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Bahrain        | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 1 | Quarter 3 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Bangladesh     | Quarter 4 | Quarter 3 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Belgium        | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Bhutan         | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Brazil         | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Canada         | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | China (Main)   | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 3 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | China (Taiwan) | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 |           |           | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Czech Rep.     | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Denmark        | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Egypt          | Quarter 4 | Quarter 1 | Quarter 3 | Quarter 1 | Quarter 3 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Finland        | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | France         | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Germany        | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Greece         | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Hungary        |           | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Indonesia      | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Iran           | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 3 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Iraq           | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 1 | Quarter 1 | Quarter 3 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Ireland        | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Israel         | Quarter 1 | Quarter 3 | Quarter 1 | Quarter 3 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 3 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Italy          | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Japan          | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Kazakhstan     | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Kenya          | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Malaysia       | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Maldives       | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 3 | Quarter 4 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Mauritius      | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Mexico         | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Myanmar        | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Nepal          | Quarter 3 | Quarter 1 | Quarter 3 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Netherlands    | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | New Zealand    | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Nigeria        | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 3 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Norway         | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Oman           | Quarter 2 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 3 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Pakistan       | Quarter 4 | Quarter 3 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Philippines    | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Poland         | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Portugal       | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Rep. of Korea  | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Russian Fed.   | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Saudi Arabia   | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 1 | Quarter 4 | Quarter 3 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Singapore      | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | South Africa   | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Spain          | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Sri Lanka      | Quarter 1 | Quarter 1 | Quarter 3 | Quarter 3 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Sudan          | Quarter 3 | Quarter 3 | Quarter 4 | Quarter 3 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Sweden         | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Switzerland    | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Tanzania       | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Thailand       | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Turkey         | Quarter 4 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | UAE            | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 1 | Quarter 4 | Quarter 3 | Quarter 3 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | UK             | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | USA            | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Ukraine        | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 4 | Quarter 1 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Vietnam        | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 4 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Yemen          | Quarter 4 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 4 | Quarter 1 | Quarter 4 | Quarter 4 | Quarter 1 |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+

# %%
print("\nTable 5: Table showing the quarter with minimum tourists coming from each country for each year and overall:")
print(tabulate(min_quarters_df, headers='keys', tablefmt='grid'))
# Out:
# Table 5: Table showing the quarter with minimum tourists coming from each country for each year and overall:
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# |                | 2013      | 2016      | 2017      | 2018      | 2019      | 2020      | 2021      | 2022      | Overall   |
# +================+===========+===========+===========+===========+===========+===========+===========+===========+===========+
# | Afghanistan    | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 4 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Argentina      | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Australia      | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Austria        | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Bahrain        | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 4 | Quarter 1 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Bangladesh     | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Belgium        | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Bhutan         | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Brazil         | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Canada         | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | China (Main)   | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | China (Taiwan) | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 |           |           | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Czech Rep.     | Quarter 2 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Denmark        | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Egypt          | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Finland        | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter3  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | France         | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Germany        | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Greece         | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Hungary        |           | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Indonesia      | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Iran           | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Iraq           | Quarter 1 | Quarter 1 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Ireland        | Quarter 3 | Quarter 2 | Quarter 3 | Quarter 2 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Israel         | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Italy          | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Japan          | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Kazakhstan     | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Kenya          | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Malaysia       | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 3 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Maldives       | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Mauritius      | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Mexico         | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Myanmar        | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter3  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Nepal          | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Netherlands    | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | New Zealand    | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Nigeria        | Quarter 2 | Quarter 4 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Norway         | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Oman           | Quarter 4 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Pakistan       | Quarter 3 | Quarter 1 | Quarter 3 | Quarter 1 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Philippines    | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Poland         | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Portugal       | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Rep. of Korea  | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Russian Fed.   | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter3  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Saudi Arabia   | Quarter 4 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Singapore      | Quarter 3 | Quarter 2 | Quarter 1 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | South Africa   | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 4 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Spain          | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Sri Lanka      | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Sudan          | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 1 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Sweden         | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter3  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Switzerland    | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Tanzania       | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Thailand       | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Turkey         | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | UAE            | Quarter 1 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | UK             | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | USA            | Quarter 3 | Quarter 2 | Quarter 3 | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Ukraine        | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 3 | Quarter 3 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Vietnam        | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 3 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
# | Yemen          | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 2 | Quarter 1 | Quarter2  |
# +----------------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+
